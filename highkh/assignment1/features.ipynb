# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %% [markdown]
# ##### 사내 서버 경로

# %%
import os
os.getcwd()
os.chdir('/root/data/highkh/cs231n/highkh/assignment1')

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # Subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]

  return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

#learning_rates = [1e-9, 1e-8, 1e-7]
#regularization_strengths = [1e5, 1e6, 1e7]

learning_rates = [7e-8, 5e-7]
regularization_strengths = [1e4, 5e4]

rand_num = 36

rand_learning_rates = []
rand_regularization_strengths = []

for i in xrange(rand_num):
    rand_learning_rates.append(random.uniform(learning_rates[0], learning_rates[1]))
    rand_regularization_strengths.append(random.uniform(regularization_strengths[0], regularization_strengths[1]))
random.shuffle(rand_learning_rates)
random.shuffle(rand_regularization_strengths)
print 'picked lr = ', rand_learning_rates
print 'picked rg = ', rand_regularization_strengths

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
rand_iter = 1
print X_train.shape
for lr, rg in zip(rand_learning_rates, rand_regularization_strengths):
    
    print 'rand iter = %d / %d' % (rand_iter, rand_num)
    bh_svm = LinearSVM()
    loss_hist = bh_svm.train(X_train_feats, y_train, learning_rate=lr, reg=rg,
                  num_iters=2000, verbose=True)
    y_train_pred = bh_svm.predict(X_train_feats)
    y_val_pred = bh_svm.predict(X_val_feats)
    train_acc = np.mean(y_train == y_train_pred)
    val_acc = np.mean(y_val == y_val_pred)
    results[(lr, rg)] = (train_acc, val_acc)
        
    if val_acc > best_val:
        best_val = val_acc
        best_svm = bh_svm
    rand_iter += 1
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# picked lr =  [2.477659690096656e-07, 9.78161620571538e-08, 1.465239430361129e-07, 3.667758627491835e-07, 4.580006481280146e-07, 1.189195612761437e-07, 3.3769486676381733e-07, 3.266726083514325e-07, 1.1445761178797229e-07, 4.89019087765742e-07, 2.1084255455244013e-07, 3.569793255254771e-07, 4.453220332903596e-07, 4.6451030475707287e-07, 4.973332402318588e-07, 3.9514504971774615e-07, 1.1775690537510596e-07, 2.565109476074942e-07, 4.585839327533673e-07, 4.6054008228550775e-07, 2.2869903964346672e-07, 2.942858742414544e-07, 4.631150184788847e-07, 1.300842563881141e-07, 2.577093449528764e-07, 4.81280412557855e-07, 4.362715263913304e-07, 2.4472008784592353e-07, 1.7442736886777315e-07, 2.1573592590355608e-07, 2.9654323508376e-07, 3.6888563807353916e-07, 1.8201579679263822e-07, 9.269567002364378e-08, 1.87645435436743e-07, 3.845256813555124e-07]
# picked rg =  [13806.13767511377, 46279.08337613094, 21226.853162927568, 48201.87297171489, 39017.37205333484, 29567.98421747766, 13969.516568294566, 21517.338174388457, 43797.47961508995, 11529.689811515955, 32846.5959309486, 25496.219309663094, 23989.577602501613, 11710.258144234174, 48187.29103932951, 32042.559785164045, 15084.987097850026, 21368.550853419838, 17511.751070931292, 29213.195664811465, 25681.448216748813, 32582.48401677791, 43812.96766695288, 12586.351224493364, 48912.890028853086, 47655.98811850444, 20581.657621500453, 48083.46232388929, 28434.266305220168, 46064.2364245828, 29234.628801621453, 29907.786040452786, 14354.499870162515, 49324.324731885776, 22129.22680280359, 16680.215486761415]
# (49000, 32, 32, 3)
# rand iter = 1 / 36
# -----------learning_rate : 2.477660e-07	 reg : 1.380614e+04----------
# iteration 0 / 2000: loss 20.027705
# iteration 100 / 2000: loss 14.548920
# iteration 200 / 2000: loss 11.790090
# iteration 300 / 2000: loss 10.401053
# iteration 400 / 2000: loss 9.703465
# iteration 500 / 2000: loss 9.354354
# iteration 600 / 2000: loss 9.177234
# iteration 700 / 2000: loss 9.088516
# iteration 800 / 2000: loss 9.043767
# iteration 900 / 2000: loss 9.021145
# iteration 1000 / 2000: loss 9.009944
# iteration 1100 / 2000: loss 9.002837
# iteration 1200 / 2000: loss 9.000390
# iteration 1300 / 2000: loss 8.998976
# iteration 1400 / 2000: loss 8.997580
# iteration 1500 / 2000: loss 8.998512
# iteration 1600 / 2000: loss 8.996898
# iteration 1700 / 2000: loss 8.997320
# iteration 1800 / 2000: loss 8.997374
# iteration 1900 / 2000: loss 8.997692
# rand iter = 2 / 36
# -----------learning_rate : 9.781616e-08	 reg : 4.627908e+04----------
# iteration 0 / 2000: loss 42.887395
# iteration 100 / 2000: loss 22.686012
# iteration 200 / 2000: loss 14.521905
# iteration 300 / 2000: loss 11.227762
# iteration 400 / 2000: loss 9.899113
# iteration 500 / 2000: loss 9.362037
# iteration 600 / 2000: loss 9.146805
# iteration 700 / 2000: loss 9.058842
# iteration 800 / 2000: loss 9.023213
# iteration 900 / 2000: loss 9.008558
# iteration 1000 / 2000: loss 9.003022
# iteration 1100 / 2000: loss 9.000991
# iteration 1200 / 2000: loss 8.999858
# iteration 1300 / 2000: loss 8.999673
# iteration 1400 / 2000: loss 8.999355
# iteration 1500 / 2000: loss 8.999293
# iteration 1600 / 2000: loss 8.999280
# iteration 1700 / 2000: loss 8.999335
# iteration 1800 / 2000: loss 8.999238
# iteration 1900 / 2000: loss 8.999252
# rand iter = 3 / 36
# -----------learning_rate : 1.465239e-07	 reg : 2.122685e+04----------
# iteration 0 / 2000: loss 26.543800
# iteration 100 / 2000: loss 18.416057
# iteration 200 / 2000: loss 14.048752
# iteration 300 / 2000: loss 11.708852
# iteration 400 / 2000: loss 10.454141
# iteration 500 / 2000: loss 9.779778
# iteration 600 / 2000: loss 9.418756
# iteration 700 / 2000: loss 9.223511
# iteration 800 / 2000: loss 9.119559
# iteration 900 / 2000: loss 9.062761
# iteration 1000 / 2000: loss 9.033373
# iteration 1100 / 2000: loss 9.016604
# iteration 1200 / 2000: loss 9.008108
# iteration 1300 / 2000: loss 9.003560
# iteration 1400 / 2000: loss 9.001359
# iteration 1500 / 2000: loss 9.000012
# iteration 1600 / 2000: loss 8.999156
# iteration 1700 / 2000: loss 8.998800
# iteration 1800 / 2000: loss 8.998417
# iteration 1900 / 2000: loss 8.998592
# rand iter = 4 / 36
# -----------learning_rate : 3.667759e-07	 reg : 4.820187e+04----------
# iteration 0 / 2000: loss 48.159216
# iteration 100 / 2000: loss 10.104633
# iteration 200 / 2000: loss 9.030324
# iteration 300 / 2000: loss 9.000131
# iteration 400 / 2000: loss 8.999283
# iteration 500 / 2000: loss 8.999298
# iteration 600 / 2000: loss 8.999189
# iteration 700 / 2000: loss 8.999351
# iteration 800 / 2000: loss 8.999447
# iteration 900 / 2000: loss 8.999205
# iteration 1000 / 2000: loss 8.999371
# iteration 1100 / 2000: loss 8.999264
# iteration 1200 / 2000: loss 8.999077
# iteration 1300 / 2000: loss 8.999221
# iteration 1400 / 2000: loss 8.999144
# iteration 1500 / 2000: loss 8.999404
# iteration 1600 / 2000: loss 8.999176
# iteration 1700 / 2000: loss 8.999220
# iteration 1800 / 2000: loss 8.999268
# iteration 1900 / 2000: loss 8.999195
# rand iter = 5 / 36
# -----------learning_rate : 4.580006e-07	 reg : 3.901737e+04----------
# iteration 0 / 2000: loss 39.487781
# iteration 100 / 2000: loss 9.827223
# iteration 200 / 2000: loss 9.022023
# iteration 300 / 2000: loss 8.999707
# iteration 400 / 2000: loss 8.999099
# iteration 500 / 2000: loss 8.999241
# iteration 600 / 2000: loss 8.999087
# iteration 700 / 2000: loss 8.999132
# iteration 800 / 2000: loss 8.999155
# iteration 900 / 2000: loss 8.998965
# iteration 1000 / 2000: loss 8.999048
# iteration 1100 / 2000: loss 8.999262
# iteration 1200 / 2000: loss 8.999023
# iteration 1300 / 2000: loss 8.999087
# iteration 1400 / 2000: loss 8.999279
# iteration 1500 / 2000: loss 8.999093
# iteration 1600 / 2000: loss 8.999029
# iteration 1700 / 2000: loss 8.999071
# iteration 1800 / 2000: loss 8.999203
# iteration 1900 / 2000: loss 8.999120
# rand iter = 6 / 36
# -----------learning_rate : 1.189196e-07	 reg : 2.956798e+04----------
# iteration 0 / 2000: loss 31.537081
# iteration 100 / 2000: loss 20.149953
# iteration 200 / 2000: loss 14.505708
# iteration 300 / 2000: loss 11.722295
# iteration 400 / 2000: loss 10.346639
# iteration 500 / 2000: loss 9.662100
# iteration 600 / 2000: loss 9.327692
# iteration 700 / 2000: loss 9.161430
# iteration 800 / 2000: loss 9.079240
# iteration 900 / 2000: loss 9.038129
# iteration 1000 / 2000: loss 9.018472
# iteration 1100 / 2000: loss 9.009012
# iteration 1200 / 2000: loss 9.003649
# iteration 1300 / 2000: loss 9.001167
# iteration 1400 / 2000: loss 9.000276
# iteration 1500 / 2000: loss 8.999285
# iteration 1600 / 2000: loss 8.999321
# iteration 1700 / 2000: loss 8.999332
# iteration 1800 / 2000: loss 8.998883
# iteration 1900 / 2000: loss 8.998704
# rand iter = 7 / 36
# -----------learning_rate : 3.376949e-07	 reg : 1.396952e+04----------
# iteration 0 / 2000: loss 19.715243
# iteration 100 / 2000: loss 13.172359
# iteration 200 / 2000: loss 10.613632
# iteration 300 / 2000: loss 9.621247
# iteration 400 / 2000: loss 9.242198
# iteration 500 / 2000: loss 9.091222
# iteration 600 / 2000: loss 9.034404
# iteration 700 / 2000: loss 9.010814
# iteration 800 / 2000: loss 9.002578
# iteration 900 / 2000: loss 8.999360
# iteration 1000 / 2000: loss 8.998689
# iteration 1100 / 2000: loss 8.997433
# iteration 1200 / 2000: loss 8.998306
# iteration 1300 / 2000: loss 8.997896
# iteration 1400 / 2000: loss 8.996923
# iteration 1500 / 2000: loss 8.997280
# iteration 1600 / 2000: loss 8.997056
# iteration 1700 / 2000: loss 8.998072
# iteration 1800 / 2000: loss 8.997901
# iteration 1900 / 2000: loss 8.997777
# rand iter = 8 / 36
# -----------learning_rate : 3.266726e-07	 reg : 2.151734e+04----------
# iteration 0 / 2000: loss 26.076015
# iteration 100 / 2000: loss 13.160212
# iteration 200 / 2000: loss 10.012015
# iteration 300 / 2000: loss 9.247618
# iteration 400 / 2000: loss 9.059309
# iteration 500 / 2000: loss 9.013440
# iteration 600 / 2000: loss 9.001471
# iteration 700 / 2000: loss 8.999178
# iteration 800 / 2000: loss 8.998632
# iteration 900 / 2000: loss 8.998254
# iteration 1000 / 2000: loss 8.998361
# iteration 1100 / 2000: loss 8.998404
# iteration 1200 / 2000: loss 8.998775
# iteration 1300 / 2000: loss 8.998493
# iteration 1400 / 2000: loss 8.998230
# iteration 1500 / 2000: loss 8.998314
# iteration 1600 / 2000: loss 8.998609
# iteration 1700 / 2000: loss 8.998398
# iteration 1800 / 2000: loss 8.998707
# iteration 1900 / 2000: loss 8.998426
# rand iter = 9 / 36
# -----------learning_rate : 1.144576e-07	 reg : 4.379748e+04----------
# iteration 0 / 2000: loss 42.610825
# iteration 100 / 2000: loss 21.296965
# iteration 200 / 2000: loss 13.494205
# iteration 300 / 2000: loss 10.646735
# iteration 400 / 2000: loss 9.603699
# iteration 500 / 2000: loss 9.221695
# iteration 600 / 2000: loss 9.079402
# iteration 700 / 2000: loss 9.028773
# iteration 800 / 2000: loss 9.010151
# iteration 900 / 2000: loss 9.003406
# iteration 1000 / 2000: loss 9.000614
# iteration 1100 / 2000: loss 8.999847
# iteration 1200 / 2000: loss 8.999497
# iteration 1300 / 2000: loss 8.999273
# iteration 1400 / 2000: loss 8.999145
# iteration 1500 / 2000: loss 8.999362
# iteration 1600 / 2000: loss 8.999116
# iteration 1700 / 2000: loss 8.999216
# iteration 1800 / 2000: loss 8.999350
# iteration 1900 / 2000: loss 8.999102
# rand iter = 10 / 36
# -----------learning_rate : 4.890191e-07	 reg : 1.152969e+04----------
# iteration 0 / 2000: loss 17.574852
# iteration 100 / 2000: loss 11.764745
# iteration 200 / 2000: loss 9.889935
# iteration 300 / 2000: loss 9.287256
# iteration 400 / 2000: loss 9.089997
# iteration 500 / 2000: loss 9.028120
# iteration 600 / 2000: loss 9.006738
# iteration 700 / 2000: loss 9.000199
# iteration 800 / 2000: loss 8.997540
# iteration 900 / 2000: loss 8.997581
# iteration 1000 / 2000: loss 8.997326
# iteration 1100 / 2000: loss 8.996645
# iteration 1200 / 2000: loss 8.996820
# iteration 1300 / 2000: loss 8.997143
# iteration 1400 / 2000: loss 8.997270
# iteration 1500 / 2000: loss 8.996594
# iteration 1600 / 2000: loss 8.996053
# iteration 1700 / 2000: loss 8.996431
# iteration 1800 / 2000: loss 8.997643
# iteration 1900 / 2000: loss 8.996864
# rand iter = 11 / 36
# -----------learning_rate : 2.108426e-07	 reg : 3.284660e+04----------
# iteration 0 / 2000: loss 33.631534
# iteration 100 / 2000: loss 15.137673
# iteration 200 / 2000: loss 10.525874
# iteration 300 / 2000: loss 9.379164
# iteration 400 / 2000: loss 9.093794
# iteration 500 / 2000: loss 9.022432
# iteration 600 / 2000: loss 9.004320
# iteration 700 / 2000: loss 9.000262
# iteration 800 / 2000: loss 8.999420
# iteration 900 / 2000: loss 8.998911
# iteration 1000 / 2000: loss 8.998624
# iteration 1100 / 2000: loss 8.998953
# iteration 1200 / 2000: loss 8.998904
# iteration 1300 / 2000: loss 8.998990
# iteration 1400 / 2000: loss 8.999073
# iteration 1500 / 2000: loss 8.998998
# iteration 1600 / 2000: loss 8.998653
# iteration 1700 / 2000: loss 8.998745
# iteration 1800 / 2000: loss 8.999241
# iteration 1900 / 2000: loss 8.998971
# rand iter = 12 / 36
# -----------learning_rate : 3.569793e-07	 reg : 2.549622e+04----------
# iteration 0 / 2000: loss 28.296654
# iteration 100 / 2000: loss 12.101322
# iteration 200 / 2000: loss 9.495372
# iteration 300 / 2000: loss 9.078692
# iteration 400 / 2000: loss 9.011053
# iteration 500 / 2000: loss 9.000704
# iteration 600 / 2000: loss 8.998932
# iteration 700 / 2000: loss 8.998730
# iteration 800 / 2000: loss 8.998485
# iteration 900 / 2000: loss 8.998635
# iteration 1000 / 2000: loss 8.998624
# iteration 1100 / 2000: loss 8.998272
# iteration 1200 / 2000: loss 8.998673
# iteration 1300 / 2000: loss 8.998797
# iteration 1400 / 2000: loss 8.998600
# iteration 1500 / 2000: loss 8.998270
# iteration 1600 / 2000: loss 8.998825
# iteration 1700 / 2000: loss 8.998720
# iteration 1800 / 2000: loss 8.998612
# iteration 1900 / 2000: loss 8.998478
# rand iter = 13 / 36
# -----------learning_rate : 4.453220e-07	 reg : 2.398958e+04----------
# iteration 0 / 2000: loss 28.282028
# iteration 100 / 2000: loss 11.244980
# iteration 200 / 2000: loss 9.260451
# iteration 300 / 2000: loss 9.029683
# iteration 400 / 2000: loss 9.002282
# iteration 500 / 2000: loss 8.998757
# iteration 600 / 2000: loss 8.998619
# iteration 700 / 2000: loss 8.998908
# iteration 800 / 2000: loss 8.998655
# iteration 900 / 2000: loss 8.998236
# iteration 1000 / 2000: loss 8.998659
# iteration 1100 / 2000: loss 8.998859
# iteration 1200 / 2000: loss 8.998591
# iteration 1300 / 2000: loss 8.998682
# iteration 1400 / 2000: loss 8.998689
# iteration 1500 / 2000: loss 8.998598
# iteration 1600 / 2000: loss 8.998498
# iteration 1700 / 2000: loss 8.998814
# iteration 1800 / 2000: loss 8.998269
# iteration 1900 / 2000: loss 8.998781
# rand iter = 14 / 36
# -----------learning_rate : 4.645103e-07	 reg : 1.171026e+04----------
# iteration 0 / 2000: loss 17.649488
# iteration 100 / 2000: loss 11.896098
# iteration 200 / 2000: loss 9.970892
# iteration 300 / 2000: loss 9.324671
# iteration 400 / 2000: loss 9.107860
# iteration 500 / 2000: loss 9.033461
# iteration 600 / 2000: loss 9.009229
# iteration 700 / 2000: loss 9.000582
# iteration 800 / 2000: loss 8.998886
# iteration 900 / 2000: loss 8.997798
# iteration 1000 / 2000: loss 8.996975
# iteration 1100 / 2000: loss 8.997601
# iteration 1200 / 2000: loss 8.997261
# iteration 1300 / 2000: loss 8.997287
# iteration 1400 / 2000: loss 8.996799
# iteration 1500 / 2000: loss 8.997386
# iteration 1600 / 2000: loss 8.997303
# iteration 1700 / 2000: loss 8.997171
# iteration 1800 / 2000: loss 8.996895
# iteration 1900 / 2000: loss 8.997380
# rand iter = 15 / 36
# -----------learning_rate : 4.973332e-07	 reg : 4.818729e+04----------
# iteration 0 / 2000: loss 46.777268
# iteration 100 / 2000: loss 9.294826
# iteration 200 / 2000: loss 9.001511
# iteration 300 / 2000: loss 8.999189
# iteration 400 / 2000: loss 8.999396
# iteration 500 / 2000: loss 8.999266
# iteration 600 / 2000: loss 8.999195
# iteration 700 / 2000: loss 8.999067
# iteration 800 / 2000: loss 8.999266
# iteration 900 / 2000: loss 8.999156
# iteration 1000 / 2000: loss 8.999230
# iteration 1100 / 2000: loss 8.999298
# iteration 1200 / 2000: loss 8.999179
# iteration 1300 / 2000: loss 8.999253
# iteration 1400 / 2000: loss 8.999308
# iteration 1500 / 2000: loss 8.999303
# iteration 1600 / 2000: loss 8.999296
# iteration 1700 / 2000: loss 8.999291
# iteration 1800 / 2000: loss 8.999303
# iteration 1900 / 2000: loss 8.999323
# rand iter = 16 / 36
# -----------learning_rate : 3.951450e-07	 reg : 3.204256e+04----------
# iteration 0 / 2000: loss 31.964481
# iteration 100 / 2000: loss 10.795410
# iteration 200 / 2000: loss 9.138721
# iteration 300 / 2000: loss 9.009396
# iteration 400 / 2000: loss 8.999747
# iteration 500 / 2000: loss 8.998828
# iteration 600 / 2000: loss 8.998936
# iteration 700 / 2000: loss 8.998951
# iteration 800 / 2000: loss 8.999001
# iteration 900 / 2000: loss 8.998972
# iteration 1000 / 2000: loss 8.999046
# iteration 1100 / 2000: loss 8.998981
# iteration 1200 / 2000: loss 8.998875
# iteration 1300 / 2000: loss 8.998990
# iteration 1400 / 2000: loss 8.999024
# iteration 1500 / 2000: loss 8.999008
# iteration 1600 / 2000: loss 8.998778
# iteration 1700 / 2000: loss 8.998886
# iteration 1800 / 2000: loss 8.998702
# iteration 1900 / 2000: loss 8.998991
# rand iter = 17 / 36
# -----------learning_rate : 1.177569e-07	 reg : 1.508499e+04----------
# iteration 0 / 2000: loss 20.642010
# iteration 100 / 2000: loss 17.172557
# iteration 200 / 2000: loss 14.720897
# iteration 300 / 2000: loss 13.003874
# iteration 400 / 2000: loss 11.805264
# iteration 500 / 2000: loss 10.967865
# iteration 600 / 2000: loss 10.377541
# iteration 700 / 2000: loss 9.961714
# iteration 800 / 2000: loss 9.675510
# iteration 900 / 2000: loss 9.473857
# iteration 1000 / 2000: loss 9.330221
# iteration 1100 / 2000: loss 9.231965
# iteration 1200 / 2000: loss 9.161154
# iteration 1300 / 2000: loss 9.109838
# iteration 1400 / 2000: loss 9.077568
# iteration 1500 / 2000: loss 9.053545
# iteration 1600 / 2000: loss 9.037380
# iteration 1700 / 2000: loss 9.025451
# iteration 1800 / 2000: loss 9.016595
# iteration 1900 / 2000: loss 9.010917
# rand iter = 18 / 36
# -----------learning_rate : 2.565109e-07	 reg : 2.136855e+04----------
# iteration 0 / 2000: loss 25.487474
# iteration 100 / 2000: loss 14.487806
# iteration 200 / 2000: loss 10.830298
# iteration 300 / 2000: loss 9.608220
# iteration 400 / 2000: loss 9.201592
# iteration 500 / 2000: loss 9.065215
# iteration 600 / 2000: loss 9.021299
# iteration 700 / 2000: loss 9.005600
# iteration 800 / 2000: loss 9.001050
# iteration 900 / 2000: loss 8.999031
# iteration 1000 / 2000: loss 8.998392
# iteration 1100 / 2000: loss 8.998242
# iteration 1200 / 2000: loss 8.998443
# iteration 1300 / 2000: loss 8.998465
# iteration 1400 / 2000: loss 8.998623
# iteration 1500 / 2000: loss 8.998189
# iteration 1600 / 2000: loss 8.998603
# iteration 1700 / 2000: loss 8.998496
# iteration 1800 / 2000: loss 8.998001
# iteration 1900 / 2000: loss 8.998547
# rand iter = 19 / 36
# -----------learning_rate : 4.585839e-07	 reg : 1.751175e+04----------
# iteration 0 / 2000: loss 22.253471
# iteration 100 / 2000: loss 11.639327
# iteration 200 / 2000: loss 9.527737
# iteration 300 / 2000: loss 9.102871
# iteration 400 / 2000: loss 9.019275
# iteration 500 / 2000: loss 9.002506
# iteration 600 / 2000: loss 8.998991
# iteration 700 / 2000: loss 8.997710
# iteration 800 / 2000: loss 8.998450
# iteration 900 / 2000: loss 8.997956
# iteration 1000 / 2000: loss 8.997732
# iteration 1100 / 2000: loss 8.998336
# iteration 1200 / 2000: loss 8.997801
# iteration 1300 / 2000: loss 8.997726
# iteration 1400 / 2000: loss 8.997827
# iteration 1500 / 2000: loss 8.998564
# iteration 1600 / 2000: loss 8.997681
# iteration 1700 / 2000: loss 8.998038
# iteration 1800 / 2000: loss 8.998241
# iteration 1900 / 2000: loss 8.998364
# rand iter = 20 / 36
# -----------learning_rate : 4.605401e-07	 reg : 2.921320e+04----------
# iteration 0 / 2000: loss 32.221010
# iteration 100 / 2000: loss 10.545658
# iteration 200 / 2000: loss 9.101950
# iteration 300 / 2000: loss 9.005420
# iteration 400 / 2000: loss 8.999376
# iteration 500 / 2000: loss 8.998912
# iteration 600 / 2000: loss 8.998562
# iteration 700 / 2000: loss 8.998711
# iteration 800 / 2000: loss 8.999053
# iteration 900 / 2000: loss 8.998887
# iteration 1000 / 2000: loss 8.998478
# iteration 1100 / 2000: loss 8.998950
# iteration 1200 / 2000: loss 8.998738
# iteration 1300 / 2000: loss 8.998741
# iteration 1400 / 2000: loss 8.998899
# iteration 1500 / 2000: loss 8.998555
# iteration 1600 / 2000: loss 8.998964
# iteration 1700 / 2000: loss 8.998857
# iteration 1800 / 2000: loss 8.998779
# iteration 1900 / 2000: loss 8.999040
# rand iter = 21 / 36
# -----------learning_rate : 2.286990e-07	 reg : 2.568145e+04----------
# iteration 0 / 2000: loss 28.649704
# iteration 100 / 2000: loss 15.049638
# iteration 200 / 2000: loss 10.861992
# iteration 300 / 2000: loss 9.572949
# iteration 400 / 2000: loss 9.175891
# iteration 500 / 2000: loss 9.051920
# iteration 600 / 2000: loss 9.015006
# iteration 700 / 2000: loss 9.003780
# iteration 800 / 2000: loss 9.000127
# iteration 900 / 2000: loss 8.999243
# iteration 1000 / 2000: loss 8.998968
# iteration 1100 / 2000: loss 8.998367
# iteration 1200 / 2000: loss 8.998844
# iteration 1300 / 2000: loss 8.998738
# iteration 1400 / 2000: loss 8.998540
# iteration 1500 / 2000: loss 8.998608
# iteration 1600 / 2000: loss 8.998482
# iteration 1700 / 2000: loss 8.998633
# iteration 1800 / 2000: loss 8.998449
# iteration 1900 / 2000: loss 8.998426
# rand iter = 22 / 36
# -----------learning_rate : 2.942859e-07	 reg : 3.258248e+04----------
# iteration 0 / 2000: loss 33.643759
# iteration 100 / 2000: loss 12.582486
# iteration 200 / 2000: loss 9.521459
# iteration 300 / 2000: loss 9.075291
# iteration 400 / 2000: loss 9.009825
# iteration 500 / 2000: loss 9.000589
# iteration 600 / 2000: loss 8.999059
# iteration 700 / 2000: loss 8.998992
# iteration 800 / 2000: loss 8.999092
# iteration 900 / 2000: loss 8.998780
# iteration 1000 / 2000: loss 8.998835
# iteration 1100 / 2000: loss 8.998777
# iteration 1200 / 2000: loss 8.998770
# iteration 1300 / 2000: loss 8.999126
# iteration 1400 / 2000: loss 8.998826
# iteration 1500 / 2000: loss 8.998900
# iteration 1600 / 2000: loss 8.999078
# iteration 1700 / 2000: loss 8.998838
# iteration 1800 / 2000: loss 8.998880
# iteration 1900 / 2000: loss 8.999032
# rand iter = 23 / 36
# -----------learning_rate : 4.631150e-07	 reg : 4.381297e+04----------
# iteration 0 / 2000: loss 44.217514
# iteration 100 / 2000: loss 9.583837
# iteration 200 / 2000: loss 9.008711
# iteration 300 / 2000: loss 8.999406
# iteration 400 / 2000: loss 8.998976
# iteration 500 / 2000: loss 8.999159
# iteration 600 / 2000: loss 8.999235
# iteration 700 / 2000: loss 8.999169
# iteration 800 / 2000: loss 8.999214
# iteration 900 / 2000: loss 8.999252
# iteration 1000 / 2000: loss 8.999076
# iteration 1100 / 2000: loss 8.999092
# iteration 1200 / 2000: loss 8.999081
# iteration 1300 / 2000: loss 8.999158
# iteration 1400 / 2000: loss 8.999230
# iteration 1500 / 2000: loss 8.999031
# iteration 1600 / 2000: loss 8.999166
# iteration 1700 / 2000: loss 8.999234
# iteration 1800 / 2000: loss 8.999072
# iteration 1900 / 2000: loss 8.999206
# rand iter = 24 / 36
# -----------learning_rate : 1.300843e-07	 reg : 1.258635e+04----------
# iteration 0 / 2000: loss 18.847554
# iteration 100 / 2000: loss 16.081342
# iteration 200 / 2000: loss 14.106538
# iteration 300 / 2000: loss 12.678501
# iteration 400 / 2000: loss 11.643721
# iteration 500 / 2000: loss 10.906656
# iteration 600 / 2000: loss 10.377960
# iteration 700 / 2000: loss 9.990806
# iteration 800 / 2000: loss 9.714627
# iteration 900 / 2000: loss 9.512701
# iteration 1000 / 2000: loss 9.368602
# iteration 1100 / 2000: loss 9.264527
# iteration 1200 / 2000: loss 9.190428
# iteration 1300 / 2000: loss 9.134209
# iteration 1400 / 2000: loss 9.096498
# iteration 1500 / 2000: loss 9.069249
# iteration 1600 / 2000: loss 9.048915
# iteration 1700 / 2000: loss 9.033682
# iteration 1800 / 2000: loss 9.024083
# iteration 1900 / 2000: loss 9.016865
# rand iter = 25 / 36
# -----------learning_rate : 2.577093e-07	 reg : 4.891289e+04----------
# iteration 0 / 2000: loss 44.455493
# iteration 100 / 2000: loss 11.802726
# iteration 200 / 2000: loss 9.220587
# iteration 300 / 2000: loss 9.016867
# iteration 400 / 2000: loss 9.000887
# iteration 500 / 2000: loss 8.999511
# iteration 600 / 2000: loss 8.999141
# iteration 700 / 2000: loss 8.999182
# iteration 800 / 2000: loss 8.999318
# iteration 900 / 2000: loss 8.999199
# iteration 1000 / 2000: loss 8.999204
# iteration 1100 / 2000: loss 8.999173
# iteration 1200 / 2000: loss 8.999323
# iteration 1300 / 2000: loss 8.999373
# iteration 1400 / 2000: loss 8.999168
# iteration 1500 / 2000: loss 8.999380
# iteration 1600 / 2000: loss 8.999371
# iteration 1700 / 2000: loss 8.999257
# iteration 1800 / 2000: loss 8.999440
# iteration 1900 / 2000: loss 8.999377
# rand iter = 26 / 36
# -----------learning_rate : 4.812804e-07	 reg : 4.765599e+04----------
# iteration 0 / 2000: loss 44.397667
# iteration 100 / 2000: loss 9.342042
# iteration 200 / 2000: loss 9.002739
# iteration 300 / 2000: loss 8.999428
# iteration 400 / 2000: loss 8.999214
# iteration 500 / 2000: loss 8.999346
# iteration 600 / 2000: loss 8.999336
# iteration 700 / 2000: loss 8.999317
# iteration 800 / 2000: loss 8.999377
# iteration 900 / 2000: loss 8.999302
# iteration 1000 / 2000: loss 8.999299
# iteration 1100 / 2000: loss 8.999218
# iteration 1200 / 2000: loss 8.999167
# iteration 1300 / 2000: loss 8.999259
# iteration 1400 / 2000: loss 8.999182
# iteration 1500 / 2000: loss 8.999291
# iteration 1600 / 2000: loss 8.999387
# iteration 1700 / 2000: loss 8.999248
# iteration 1800 / 2000: loss 8.999249
# iteration 1900 / 2000: loss 8.999468
# rand iter = 27 / 36
# -----------learning_rate : 4.362715e-07	 reg : 2.058166e+04----------
# iteration 0 / 2000: loss 24.069993
# iteration 100 / 2000: loss 11.481838
# iteration 200 / 2000: loss 9.406763
# iteration 300 / 2000: loss 9.065046
# iteration 400 / 2000: loss 9.010103
# iteration 500 / 2000: loss 9.000163
# iteration 600 / 2000: loss 8.998627
# iteration 700 / 2000: loss 8.998582
# iteration 800 / 2000: loss 8.997971
# iteration 900 / 2000: loss 8.998289
# iteration 1000 / 2000: loss 8.998158
# iteration 1100 / 2000: loss 8.998523
# iteration 1200 / 2000: loss 8.998361
# iteration 1300 / 2000: loss 8.998268
# iteration 1400 / 2000: loss 8.998159
# iteration 1500 / 2000: loss 8.998473
# iteration 1600 / 2000: loss 8.998551
# iteration 1700 / 2000: loss 8.997923
# iteration 1800 / 2000: loss 8.998282
# iteration 1900 / 2000: loss 8.998421
# rand iter = 28 / 36
# -----------learning_rate : 2.447201e-07	 reg : 4.808346e+04----------
# iteration 0 / 2000: loss 46.154906
# iteration 100 / 2000: loss 12.484689
# iteration 200 / 2000: loss 9.325934
# iteration 300 / 2000: loss 9.029505
# iteration 400 / 2000: loss 9.002148
# iteration 500 / 2000: loss 8.999644
# iteration 600 / 2000: loss 8.999360
# iteration 700 / 2000: loss 8.999309
# iteration 800 / 2000: loss 8.999277
# iteration 900 / 2000: loss 8.999127
# iteration 1000 / 2000: loss 8.999296
# iteration 1100 / 2000: loss 8.999306
# iteration 1200 / 2000: loss 8.999304
# iteration 1300 / 2000: loss 8.999323
# iteration 1400 / 2000: loss 8.999465
# iteration 1500 / 2000: loss 8.999256
# iteration 1600 / 2000: loss 8.999284
# iteration 1700 / 2000: loss 8.999176
# iteration 1800 / 2000: loss 8.999195
# iteration 1900 / 2000: loss 8.999424
# rand iter = 29 / 36
# -----------learning_rate : 1.744274e-07	 reg : 2.843427e+04----------
# iteration 0 / 2000: loss 30.471807
# iteration 100 / 2000: loss 16.947432
# iteration 200 / 2000: loss 11.939634
# iteration 300 / 2000: loss 10.084274
# iteration 400 / 2000: loss 9.400001
# iteration 500 / 2000: loss 9.147345
# iteration 600 / 2000: loss 9.054208
# iteration 700 / 2000: loss 9.018975
# iteration 800 / 2000: loss 9.006140
# iteration 900 / 2000: loss 9.001910
# iteration 1000 / 2000: loss 9.000073
# iteration 1100 / 2000: loss 8.999000
# iteration 1200 / 2000: loss 8.999076
# iteration 1300 / 2000: loss 8.998902
# iteration 1400 / 2000: loss 8.998673
# iteration 1500 / 2000: loss 8.998550
# iteration 1600 / 2000: loss 8.998544
# iteration 1700 / 2000: loss 8.998739
# iteration 1800 / 2000: loss 8.999046
# iteration 1900 / 2000: loss 8.998817
# rand iter = 30 / 36
# -----------learning_rate : 2.157359e-07	 reg : 4.606424e+04----------
# iteration 0 / 2000: loss 44.863030
# iteration 100 / 2000: loss 13.865760
# iteration 200 / 2000: loss 9.658431
# iteration 300 / 2000: loss 9.088274
# iteration 400 / 2000: loss 9.011481
# iteration 500 / 2000: loss 9.000995
# iteration 600 / 2000: loss 8.999565
# iteration 700 / 2000: loss 8.999280
# iteration 800 / 2000: loss 8.999112
# iteration 900 / 2000: loss 8.999053
# iteration 1000 / 2000: loss 8.999206
# iteration 1100 / 2000: loss 8.998977
# iteration 1200 / 2000: loss 8.999287
# iteration 1300 / 2000: loss 8.999326
# iteration 1400 / 2000: loss 8.999127
# iteration 1500 / 2000: loss 8.999338
# iteration 1600 / 2000: loss 8.999066
# iteration 1700 / 2000: loss 8.999203
# iteration 1800 / 2000: loss 8.999413
# iteration 1900 / 2000: loss 8.999101
# rand iter = 31 / 36
# -----------learning_rate : 2.965432e-07	 reg : 2.923463e+04----------
# iteration 0 / 2000: loss 31.495616
# iteration 100 / 2000: loss 12.937267
# iteration 200 / 2000: loss 9.689884
# iteration 300 / 2000: loss 9.119402
# iteration 400 / 2000: loss 9.020410
# iteration 500 / 2000: loss 9.002596
# iteration 600 / 2000: loss 8.999403
# iteration 700 / 2000: loss 8.998753
# iteration 800 / 2000: loss 8.998767
# iteration 900 / 2000: loss 8.998641
# iteration 1000 / 2000: loss 8.999404
# iteration 1100 / 2000: loss 8.999099
# iteration 1200 / 2000: loss 8.998859
# iteration 1300 / 2000: loss 8.998679
# iteration 1400 / 2000: loss 8.998923
# iteration 1500 / 2000: loss 8.998760
# iteration 1600 / 2000: loss 8.998931
# iteration 1700 / 2000: loss 8.999092
# iteration 1800 / 2000: loss 8.998871
# iteration 1900 / 2000: loss 8.998813
# rand iter = 32 / 36
# -----------learning_rate : 3.688856e-07	 reg : 2.990779e+04----------
# iteration 0 / 2000: loss 32.865420
# iteration 100 / 2000: loss 11.588699
# iteration 200 / 2000: loss 9.281696
# iteration 300 / 2000: loss 9.029489
# iteration 400 / 2000: loss 9.002138
# iteration 500 / 2000: loss 8.999195
# iteration 600 / 2000: loss 8.998935
# iteration 700 / 2000: loss 8.998691
# iteration 800 / 2000: loss 8.998654
# iteration 900 / 2000: loss 8.999108
# iteration 1000 / 2000: loss 8.998767
# iteration 1100 / 2000: loss 8.999009
# iteration 1200 / 2000: loss 8.998640
# iteration 1300 / 2000: loss 8.998770
# iteration 1400 / 2000: loss 8.998956
# iteration 1500 / 2000: loss 8.998874
# iteration 1600 / 2000: loss 8.998761
# iteration 1700 / 2000: loss 8.998360
# iteration 1800 / 2000: loss 8.998768
# iteration 1900 / 2000: loss 8.998830
# rand iter = 33 / 36
# -----------learning_rate : 1.820158e-07	 reg : 1.435450e+04----------
# iteration 0 / 2000: loss 20.094620
# iteration 100 / 2000: loss 15.564183
# iteration 200 / 2000: loss 12.895040
# iteration 300 / 2000: loss 11.310645
# iteration 400 / 2000: loss 10.364373
# iteration 500 / 2000: loss 9.807234
# iteration 600 / 2000: loss 9.479748
# iteration 700 / 2000: loss 9.284297
# iteration 800 / 2000: loss 9.168277
# iteration 900 / 2000: loss 9.098630
# iteration 1000 / 2000: loss 9.057413
# iteration 1100 / 2000: loss 9.033396
# iteration 1200 / 2000: loss 9.017664
# iteration 1300 / 2000: loss 9.009314
# iteration 1400 / 2000: loss 9.005495
# iteration 1500 / 2000: loss 9.001079
# iteration 1600 / 2000: loss 8.999660
# iteration 1700 / 2000: loss 8.999227
# iteration 1800 / 2000: loss 8.998588
# iteration 1900 / 2000: loss 8.997990
# rand iter = 34 / 36
# -----------learning_rate : 9.269567e-08	 reg : 4.932432e+04----------
# iteration 0 / 2000: loss 45.073107
# iteration 100 / 2000: loss 23.430011
# iteration 200 / 2000: loss 14.771322
# iteration 300 / 2000: loss 11.304741
# iteration 400 / 2000: loss 9.920110
# iteration 500 / 2000: loss 9.368135
# iteration 600 / 2000: loss 9.147996
# iteration 700 / 2000: loss 9.058164
# iteration 800 / 2000: loss 9.022795
# iteration 900 / 2000: loss 9.008908
# iteration 1000 / 2000: loss 9.003218
# iteration 1100 / 2000: loss 9.000858
# iteration 1200 / 2000: loss 9.000052
# iteration 1300 / 2000: loss 8.999462
# iteration 1400 / 2000: loss 8.999322
# iteration 1500 / 2000: loss 8.999147
# iteration 1600 / 2000: loss 8.999248
# iteration 1700 / 2000: loss 8.999146
# iteration 1800 / 2000: loss 8.999317
# iteration 1900 / 2000: loss 8.999344
# rand iter = 35 / 36
# -----------learning_rate : 1.876454e-07	 reg : 2.212923e+04----------
# iteration 0 / 2000: loss 26.223432
# iteration 100 / 2000: loss 16.490030
# iteration 200 / 2000: loss 12.256528
# iteration 300 / 2000: loss 10.415501
# iteration 400 / 2000: loss 9.614611
# iteration 500 / 2000: loss 9.268952
# iteration 600 / 2000: loss 9.114580
# iteration 700 / 2000: loss 9.048599
# iteration 800 / 2000: loss 9.019681
# iteration 900 / 2000: loss 9.007456
# iteration 1000 / 2000: loss 9.002758
# iteration 1100 / 2000: loss 9.000500
# iteration 1200 / 2000: loss 8.999397
# iteration 1300 / 2000: loss 8.999039
# iteration 1400 / 2000: loss 8.998546
# iteration 1500 / 2000: loss 8.998131
# iteration 1600 / 2000: loss 8.998076
# iteration 1700 / 2000: loss 8.998526
# iteration 1800 / 2000: loss 8.998559
# iteration 1900 / 2000: loss 8.998857
# rand iter = 36 / 36
# -----------learning_rate : 3.845257e-07	 reg : 1.668022e+04----------
# iteration 0 / 2000: loss 22.394684
# iteration 100 / 2000: loss 12.696351
# iteration 200 / 2000: loss 10.014294
# iteration 300 / 2000: loss 9.279543
# iteration 400 / 2000: loss 9.075560
# iteration 500 / 2000: loss 9.019155
# iteration 600 / 2000: loss 9.003610
# iteration 700 / 2000: loss 8.999184
# iteration 800 / 2000: loss 8.998050
# iteration 900 / 2000: loss 8.998004
# iteration 1000 / 2000: loss 8.997425
# iteration 1100 / 2000: loss 8.997483
# iteration 1200 / 2000: loss 8.997930
# iteration 1300 / 2000: loss 8.998292
# iteration 1400 / 2000: loss 8.997977
# iteration 1500 / 2000: loss 8.998019
# iteration 1600 / 2000: loss 8.998203
# iteration 1700 / 2000: loss 8.997700
# iteration 1800 / 2000: loss 8.997528
# iteration 1900 / 2000: loss 8.998285
# lr 9.269567e-08 reg 4.932432e+04 train accuracy: 0.412939 val accuracy: 0.412000
# lr 9.781616e-08 reg 4.627908e+04 train accuracy: 0.417796 val accuracy: 0.422000
# lr 1.144576e-07 reg 4.379748e+04 train accuracy: 0.412469 val accuracy: 0.421000
# lr 1.177569e-07 reg 1.508499e+04 train accuracy: 0.296163 val accuracy: 0.289000
# lr 1.189196e-07 reg 2.956798e+04 train accuracy: 0.413633 val accuracy: 0.405000
# lr 1.300843e-07 reg 1.258635e+04 train accuracy: 0.270653 val accuracy: 0.268000
# lr 1.465239e-07 reg 2.122685e+04 train accuracy: 0.415184 val accuracy: 0.406000
# lr 1.744274e-07 reg 2.843427e+04 train accuracy: 0.417000 val accuracy: 0.413000
# lr 1.820158e-07 reg 1.435450e+04 train accuracy: 0.403571 val accuracy: 0.396000
# lr 1.876454e-07 reg 2.212923e+04 train accuracy: 0.414694 val accuracy: 0.416000
# lr 2.108426e-07 reg 3.284660e+04 train accuracy: 0.415265 val accuracy: 0.414000
# lr 2.157359e-07 reg 4.606424e+04 train accuracy: 0.412551 val accuracy: 0.421000
# lr 2.286990e-07 reg 2.568145e+04 train accuracy: 0.413531 val accuracy: 0.418000
# lr 2.447201e-07 reg 4.808346e+04 train accuracy: 0.416469 val accuracy: 0.421000
# lr 2.477660e-07 reg 1.380614e+04 train accuracy: 0.416082 val accuracy: 0.415000
# lr 2.565109e-07 reg 2.136855e+04 train accuracy: 0.416939 val accuracy: 0.420000
# lr 2.577093e-07 reg 4.891289e+04 train accuracy: 0.414796 val accuracy: 0.413000
# lr 2.942859e-07 reg 3.258248e+04 train accuracy: 0.414265 val accuracy: 0.411000
# lr 2.965432e-07 reg 2.923463e+04 train accuracy: 0.413796 val accuracy: 0.417000
# lr 3.266726e-07 reg 2.151734e+04 train accuracy: 0.414592 val accuracy: 0.415000
# lr 3.376949e-07 reg 1.396952e+04 train accuracy: 0.416408 val accuracy: 0.423000
# lr 3.569793e-07 reg 2.549622e+04 train accuracy: 0.418490 val accuracy: 0.415000
# lr 3.667759e-07 reg 4.820187e+04 train accuracy: 0.412429 val accuracy: 0.405000
# lr 3.688856e-07 reg 2.990779e+04 train accuracy: 0.414408 val accuracy: 0.415000
# lr 3.845257e-07 reg 1.668022e+04 train accuracy: 0.412122 val accuracy: 0.421000
# lr 3.951450e-07 reg 3.204256e+04 train accuracy: 0.419898 val accuracy: 0.424000
# lr 4.362715e-07 reg 2.058166e+04 train accuracy: 0.416347 val accuracy: 0.413000
# lr 4.453220e-07 reg 2.398958e+04 train accuracy: 0.411673 val accuracy: 0.408000
# lr 4.580006e-07 reg 3.901737e+04 train accuracy: 0.415898 val accuracy: 0.415000
# lr 4.585839e-07 reg 1.751175e+04 train accuracy: 0.417837 val accuracy: 0.417000
# lr 4.605401e-07 reg 2.921320e+04 train accuracy: 0.417061 val accuracy: 0.425000
# lr 4.631150e-07 reg 4.381297e+04 train accuracy: 0.416776 val accuracy: 0.422000
# lr 4.645103e-07 reg 1.171026e+04 train accuracy: 0.413857 val accuracy: 0.416000
# lr 4.812804e-07 reg 4.765599e+04 train accuracy: 0.409184 val accuracy: 0.410000
# lr 4.890191e-07 reg 1.152969e+04 train accuracy: 0.416306 val accuracy: 0.417000
# lr 4.973332e-07 reg 4.818729e+04 train accuracy: 0.414490 val accuracy: 0.418000
# best validation accuracy achieved during cross-validation: 0.425000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print test_accuracy
# Out:
# 0.431

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print X_train_feats.shape
# Out:
# (49000, 155)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################

rand_num = 5
iter_num = 5000

learning_rates = [4e-1, 6e-1]
regularization_strengths = [0, 1e-6]

rand_learning_rates = []
rand_regularization_strengths = []

for i in xrange(rand_num):
    rand_learning_rates.append(random.uniform(learning_rates[0], learning_rates[1]))
    rand_regularization_strengths.append(random.uniform(regularization_strengths[0], regularization_strengths[1]))
random.shuffle(rand_learning_rates)
random.shuffle(rand_regularization_strengths)
print 'picked lr = ', rand_learning_rates
print 'picked rg = ', rand_regularization_strengths

results = {}
best_stats = None
best_val = -1

rand_iter = 1
for lr, rg in zip(rand_learning_rates, rand_regularization_strengths):
    print 'rand iter = %d / %d' % (rand_iter, rand_num)

    net = TwoLayerNet(input_dim, hidden_dim, num_classes)

        # Train the network
    stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
            num_iters=iter_num, batch_size=200,
            learning_rate=lr, learning_rate_decay=0.95,
            reg=rg, verbose=False)

    y_train_pred = net.predict(X_train_feats)
    acc_train = np.mean(y_train == y_train_pred)
    y_val_pred = net.predict(X_val_feats)
    acc_val = np.mean(y_val == y_val_pred)

    results[(lr, rg)] = (acc_train, acc_val)

    if best_val < acc_val:
        best_stats = stats
        best_val = acc_val
        best_net = net
    rand_iter += 1

for lr, rg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, rg)]
    print 'lr %e rg %e train accuracy: %f val accuracy: %f' % (
                lr, rg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val    

################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# picked lr =  [0.4899103081134029, 0.4874382005880797, 0.5111539569712409, 0.502495416935789, 0.4228433243643363]
# picked rg =  [4.450557209452752e-07, 5.025296584995056e-07, 6.45309918843815e-07, 5.634556893494248e-07, 1.0414215078475164e-07]
# rand iter = 1 / 5
# rand iter = 2 / 5
# rand iter = 3 / 5
# rand iter = 4 / 5
# rand iter = 5 / 5
# lr 4.228433e-01 rg 1.041422e-07 train accuracy: 0.866653 val accuracy: 0.585000
# lr 4.874382e-01 rg 5.025297e-07 train accuracy: 0.884714 val accuracy: 0.582000
# lr 4.899103e-01 rg 4.450557e-07 train accuracy: 0.887898 val accuracy: 0.568000
# lr 5.024954e-01 rg 5.634557e-07 train accuracy: 0.886898 val accuracy: 0.584000
# lr 5.111540e-01 rg 6.453099e-07 train accuracy: 0.889735 val accuracy: 0.596000
# best validation accuracy achieved during cross-validation: 0.596000

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (net.predict(X_test_feats) == y_test).mean()
print test_acc
# Out:
# 0.582

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
